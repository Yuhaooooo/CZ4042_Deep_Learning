# %%
import pylab as plt
import multiprocessing as mp
from train import train, epochs
# Out:
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def main():
    params = []
    param = {}
    param['weight_decay_parameter'] = 1e-6
    param['batch_size'] = 32
    param['hidden_layer_neuron_num'] = 10
    param['required'] = 'train accuracy and test accuracy'
    param['hidden_layer_num'] = 1
    params.append(param)
    
    accs = []
    for param in params:
        acc = train(param)
        accs.append(acc)
        
    plt.figure()
    for i in range(len(params)):
        plt.plot(range(epochs), accs[i][0], label='Train Accuracy')
        plt.plot(range(epochs), accs[i][1], label='Test Accuracy')
        
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:141: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:144: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:57: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:74: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:75: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# iter 100: train accuracy 0.862231
# iter 100: test accuracy 0.884013
# iter 200: train accuracy 0.883737
# iter 200: test accuracy 0.898119
# iter 300: train accuracy 0.888441
# iter 300: test accuracy 0.904389
# iter 400: train accuracy 0.895161
# iter 400: test accuracy 0.902821
# iter 500: train accuracy 0.899866
# iter 500: test accuracy 0.905956
# iter 600: train accuracy 0.90121
# iter 600: test accuracy 0.907524
# iter 700: train accuracy 0.90121
# iter 700: test accuracy 0.909091
# iter 800: train accuracy 0.903226
# iter 800: test accuracy 0.913793
# iter 900: train accuracy 0.905242
# iter 900: test accuracy 0.912226
# iter 1000: train accuracy 0.90457
# iter 1000: test accuracy 0.910658
# iter 1100: train accuracy 0.903226
# iter 1100: test accuracy 0.910658
# iter 1200: train accuracy 0.90457
# iter 1200: test accuracy 0.910658
# iter 1300: train accuracy 0.903898
# iter 1300: test accuracy 0.907524
# iter 1400: train accuracy 0.905914
# iter 1400: test accuracy 0.907524
# iter 1500: train accuracy 0.909274
# iter 1500: test accuracy 0.907524
# iter 1600: train accuracy 0.909946
# iter 1600: test accuracy 0.905956
# iter 1700: train accuracy 0.91129
# iter 1700: test accuracy 0.904389
# iter 1800: train accuracy 0.912634
# iter 1800: test accuracy 0.902821
# iter 1900: train accuracy 0.913979
# iter 1900: test accuracy 0.902821
# iter 2000: train accuracy 0.914651
# iter 2000: test accuracy 0.904389
# iter 2100: train accuracy 0.916667
# iter 2100: test accuracy 0.905956
# iter 2200: train accuracy 0.916667
# iter 2200: test accuracy 0.905956
# iter 2300: train accuracy 0.915323
# iter 2300: test accuracy 0.904389
# iter 2400: train accuracy 0.915323
# iter 2400: test accuracy 0.904389
# iter 2500: train accuracy 0.915323
# iter 2500: test accuracy 0.902821
# iter 2600: train accuracy 0.915995
# iter 2600: test accuracy 0.904389
# iter 2700: train accuracy 0.915323
# iter 2700: test accuracy 0.904389
# iter 2800: train accuracy 0.914651
# iter 2800: test accuracy 0.905956
# iter 2900: train accuracy 0.913979
# iter 2900: test accuracy 0.904389
# iter 3000: train accuracy 0.914651
# iter 3000: test accuracy 0.905956
# iter 3100: train accuracy 0.916667
# iter 3100: test accuracy 0.905956
# iter 3200: train accuracy 0.916667
# iter 3200: test accuracy 0.904389
# iter 3300: train accuracy 0.916667
# iter 3300: test accuracy 0.904389
# iter 3400: train accuracy 0.918683
# iter 3400: test accuracy 0.904389
# iter 3500: train accuracy 0.919355
# iter 3500: test accuracy 0.904389
# iter 3600: train accuracy 0.919355
# iter 3600: test accuracy 0.907524
# iter 3700: train accuracy 0.919355
# iter 3700: test accuracy 0.907524
# iter 3800: train accuracy 0.919355
# iter 3800: test accuracy 0.905956
# iter 3900: train accuracy 0.920027
# iter 3900: test accuracy 0.907524
# iter 4000: train accuracy 0.920027
# iter 4000: test accuracy 0.907524
# iter 4100: train accuracy 0.919355
# iter 4100: test accuracy 0.907524
# iter 4200: train accuracy 0.919355
# iter 4200: test accuracy 0.907524
# iter 4300: train accuracy 0.919355
# iter 4300: test accuracy 0.909091
# iter 4400: train accuracy 0.921371
# iter 4400: test accuracy 0.909091
# iter 4500: train accuracy 0.920699
# iter 4500: test accuracy 0.909091
# iter 4600: train accuracy 0.920699
# iter 4600: test accuracy 0.909091
# iter 4700: train accuracy 0.920699
# iter 4700: test accuracy 0.907524
# iter 4800: train accuracy 0.920027
# iter 4800: test accuracy 0.907524
# iter 4900: train accuracy 0.920699
# iter 4900: test accuracy 0.907524
# iter 5000: train accuracy 0.920699
# iter 5000: test accuracy 0.907524
