# %%
import pylab as plt
import multiprocessing as mp
from train import train, epochs
# Out:
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def main():
    params = []
    param = {}
    param['weight_decay_parameter'] = 1e-6
    param['batch_size'] = 32
    param['hidden_layer_neuron_num'] = 10
    param['required'] = 'train accuracy and test accuracy'
    param['hidden_layer_num'] = 1
    params.append(param)
    
    accs = []
    for param in params:
        acc = train(param)
        accs.append(acc)
        
    plt.figure()
    for i in range(len(params)):
        plt.plot(range(epochs), accs[i][0], label='Train Accuracy')
        plt.plot(range(epochs), accs[i][1], label='Test Accuracy')
        
    plt.xlabel('epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:44: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:48: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:73: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:83: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1_question_a\train.py:84: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# iter 100: train accuracy 0.861559
# iter 100: test accuracy 0.747649
# iter 200: train accuracy 0.899194
# iter 200: test accuracy 0.768025
# iter 300: train accuracy 0.909274
# iter 300: test accuracy 0.761755
# iter 400: train accuracy 0.905914
# iter 400: test accuracy 0.747649
# iter 500: train accuracy 0.902554
# iter 500: test accuracy 0.736677
# iter 600: train accuracy 0.901882
# iter 600: test accuracy 0.730408
# iter 700: train accuracy 0.901882
# iter 700: test accuracy 0.727273
# iter 800: train accuracy 0.903898
# iter 800: test accuracy 0.725705
# iter 900: train accuracy 0.903898
# iter 900: test accuracy 0.727273
# iter 1000: train accuracy 0.903898
# iter 1000: test accuracy 0.725705
# iter 1100: train accuracy 0.90457
# iter 1100: test accuracy 0.717868
# iter 1200: train accuracy 0.907258
# iter 1200: test accuracy 0.719436
# iter 1300: train accuracy 0.909274
# iter 1300: test accuracy 0.710031
# iter 1400: train accuracy 0.912634
# iter 1400: test accuracy 0.711599
# iter 1500: train accuracy 0.917339
# iter 1500: test accuracy 0.711599
# iter 1600: train accuracy 0.918011
# iter 1600: test accuracy 0.711599
# iter 1700: train accuracy 0.918683
# iter 1700: test accuracy 0.711599
# iter 1800: train accuracy 0.919355
# iter 1800: test accuracy 0.713166
# iter 1900: train accuracy 0.919355
# iter 1900: test accuracy 0.717868
# iter 2000: train accuracy 0.920027
# iter 2000: test accuracy 0.717868
# iter 2100: train accuracy 0.920699
# iter 2100: test accuracy 0.713166
# iter 2200: train accuracy 0.920699
# iter 2200: test accuracy 0.713166
# iter 2300: train accuracy 0.922715
# iter 2300: test accuracy 0.710031
# iter 2400: train accuracy 0.923387
# iter 2400: test accuracy 0.711599
# iter 2500: train accuracy 0.925403
# iter 2500: test accuracy 0.711599
# iter 2600: train accuracy 0.924731
# iter 2600: test accuracy 0.714734
# iter 2700: train accuracy 0.925403
# iter 2700: test accuracy 0.713166
# iter 2800: train accuracy 0.926075
# iter 2800: test accuracy 0.713166
# iter 2900: train accuracy 0.926747
# iter 2900: test accuracy 0.713166
# iter 3000: train accuracy 0.928763
# iter 3000: test accuracy 0.714734
# iter 3100: train accuracy 0.930108
# iter 3100: test accuracy 0.711599
# iter 3200: train accuracy 0.929435
# iter 3200: test accuracy 0.710031
# iter 3300: train accuracy 0.930108
# iter 3300: test accuracy 0.710031
# iter 3400: train accuracy 0.93078
# iter 3400: test accuracy 0.710031
# iter 3500: train accuracy 0.93078
# iter 3500: test accuracy 0.705329
# iter 3600: train accuracy 0.93078
# iter 3600: test accuracy 0.703762
# iter 3700: train accuracy 0.93078
# iter 3700: test accuracy 0.700627
# iter 3800: train accuracy 0.93078
# iter 3800: test accuracy 0.697492
# iter 3900: train accuracy 0.931452
# iter 3900: test accuracy 0.697492
# iter 4000: train accuracy 0.932124
# iter 4000: test accuracy 0.695925
# iter 4100: train accuracy 0.932796
# iter 4100: test accuracy 0.691223
# iter 4200: train accuracy 0.934812
# iter 4200: test accuracy 0.684953
# iter 4300: train accuracy 0.935484
# iter 4300: test accuracy 0.684953
# iter 4400: train accuracy 0.938172
# iter 4400: test accuracy 0.683386
# iter 4500: train accuracy 0.939516
# iter 4500: test accuracy 0.680251
# iter 4600: train accuracy 0.939516
# iter 4600: test accuracy 0.678683
# iter 4700: train accuracy 0.939516
# iter 4700: test accuracy 0.678683
# iter 4800: train accuracy 0.938844
# iter 4800: test accuracy 0.677116
# iter 4900: train accuracy 0.938844
# iter 4900: test accuracy 0.678683
# iter 5000: train accuracy 0.939516
# iter 5000: test accuracy 0.678683
