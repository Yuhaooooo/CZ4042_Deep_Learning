# %%
import pylab as plt
import multiprocessing as mp
from train import train, epochs, get_data

def main():
    params = []
    param1 = {}
    param1['weight_decay_parameter'] = 0
    param1['batch_size'] = 8
    param1['hidden_layer_neuron_num'] = 25
    param1['required'] = 'cross-validation accuracy'
    param1['hidden_layer_num'] = 1
    param2 = param1.copy()
    param3 = param1.copy()
    param4 = param1.copy()
    param5 = param1.copy()
    
    params.append(param1)
    param2['weight_decay_parameter'] = 1e-3
    params.append(param2)
    param3['weight_decay_parameter'] = 1e-6
    params.append(param3)
    param4['weight_decay_parameter'] = 1e-9
    params.append(param4)
    param5['weight_decay_parameter'] = 1e-12
    params.append(param5)
    no_threads = mp.cpu_count()
    p = mp.Pool(processes=no_threads)
    accs = p.map(train, params)
    plt.figure()
    for i in range(len(params)):
        plt.plot(range(epochs), accs[i][0], label='Weight decay parameter:'
                 + str(params[i]['weight_decay_parameter']))
    plt.xlabel('Epochs')
    plt.ylabel('Cross Validation Accuracy')
    plt.legend()
    plt.savefig('Q4ab.png', bbox_inches='tight', dpi=100)
    plt.show()
    
    # plot for (c)
    param1['required'] = 'train accuracy and test accuracy'
    acc = train(param1)
    plt.figure()
    plt.plot(range(epochs), acc[0], label='Train Accuracy')
    plt.plot(range(epochs), acc[1], label='Test Accuracy')  
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig('Q4c.png', bbox_inches='tight', dpi=100)
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\python\python36\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# d:\python\python36\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1\assignment1_question_a\train.py:124: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1\assignment1_question_a\train.py:127: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1\assignment1_question_a\train.py:198: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1\assignment1_question_a\train.py:55: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From D:\GitHub Projects\CZ042_Deep_Learning\assignment1\assignment1_question_a\train.py:56: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# iter 100: train accuracy 0.907258
# iter 100: test accuracy 0.877743
# iter 200: train accuracy 0.915323
# iter 200: test accuracy 0.88558
# iter 300: train accuracy 0.924731
# iter 300: test accuracy 0.902821
# iter 400: train accuracy 0.928091
# iter 400: test accuracy 0.905956
# iter 500: train accuracy 0.929435
# iter 500: test accuracy 0.904389
# iter 600: train accuracy 0.936156
# iter 600: test accuracy 0.896552
# iter 700: train accuracy 0.93414
# iter 700: test accuracy 0.894984
# iter 800: train accuracy 0.93414
# iter 800: test accuracy 0.896552
# iter 900: train accuracy 0.938172
# iter 900: test accuracy 0.896552
# iter 1000: train accuracy 0.940188
# iter 1000: test accuracy 0.907524
# iter 1100: train accuracy 0.94422
# iter 1100: test accuracy 0.904389
# iter 1200: train accuracy 0.94422
# iter 1200: test accuracy 0.894984
# iter 1300: train accuracy 0.939516
# iter 1300: test accuracy 0.890282
# iter 1400: train accuracy 0.950269
# iter 1400: test accuracy 0.904389
# iter 1500: train accuracy 0.943548
# iter 1500: test accuracy 0.904389
# iter 1600: train accuracy 0.951613
# iter 1600: test accuracy 0.901254
# iter 1700: train accuracy 0.949597
# iter 1700: test accuracy 0.902821
# iter 1800: train accuracy 0.949597
# iter 1800: test accuracy 0.907524
# iter 1900: train accuracy 0.953629
# iter 1900: test accuracy 0.909091
# iter 2000: train accuracy 0.952957
# iter 2000: test accuracy 0.910658
# iter 2100: train accuracy 0.957661
# iter 2100: test accuracy 0.904389
# iter 2200: train accuracy 0.948925
# iter 2200: test accuracy 0.902821
# iter 2300: train accuracy 0.956317
# iter 2300: test accuracy 0.909091
# iter 2400: train accuracy 0.947581
# iter 2400: test accuracy 0.902821
# iter 2500: train accuracy 0.944892
# iter 2500: test accuracy 0.898119
# iter 2600: train accuracy 0.955645
# iter 2600: test accuracy 0.899687
# iter 2700: train accuracy 0.960349
# iter 2700: test accuracy 0.912226
# iter 2800: train accuracy 0.96371
# iter 2800: test accuracy 0.916928
# iter 2900: train accuracy 0.96371
# iter 2900: test accuracy 0.912226
# iter 3000: train accuracy 0.956989
# iter 3000: test accuracy 0.912226
# iter 3100: train accuracy 0.96707
# iter 3100: test accuracy 0.918495
# iter 3200: train accuracy 0.962366
# iter 3200: test accuracy 0.913793
# iter 3300: train accuracy 0.96707
# iter 3300: test accuracy 0.916928
# iter 3400: train accuracy 0.96707
# iter 3400: test accuracy 0.916928
# iter 3500: train accuracy 0.960349
# iter 3500: test accuracy 0.915361
# iter 3600: train accuracy 0.964382
# iter 3600: test accuracy 0.915361
# iter 3700: train accuracy 0.961021
# iter 3700: test accuracy 0.913793
# iter 3800: train accuracy 0.959677
# iter 3800: test accuracy 0.905956
# iter 3900: train accuracy 0.969086
# iter 3900: test accuracy 0.905956
# iter 4000: train accuracy 0.966398
# iter 4000: test accuracy 0.915361
# iter 4100: train accuracy 0.969086
# iter 4100: test accuracy 0.913793
# iter 4200: train accuracy 0.967742
# iter 4200: test accuracy 0.909091
# iter 4300: train accuracy 0.97043
# iter 4300: test accuracy 0.916928
# iter 4400: train accuracy 0.973118
# iter 4400: test accuracy 0.904389
# iter 4500: train accuracy 0.969086
# iter 4500: test accuracy 0.909091
# iter 4600: train accuracy 0.96371
# iter 4600: test accuracy 0.909091
# iter 4700: train accuracy 0.97379
# iter 4700: test accuracy 0.905956
# iter 4800: train accuracy 0.97379
# iter 4800: test accuracy 0.909091
# iter 4900: train accuracy 0.971102
# iter 4900: test accuracy 0.918495
# iter 5000: train accuracy 0.962366
# iter 5000: test accuracy 0.896552
# iter 5100: train accuracy 0.972446
# iter 5100: test accuracy 0.913793
# iter 5200: train accuracy 0.973118
# iter 5200: test accuracy 0.913793
# iter 5300: train accuracy 0.97043
# iter 5300: test accuracy 0.918495
# iter 5400: train accuracy 0.972446
# iter 5400: test accuracy 0.909091
# iter 5500: train accuracy 0.971102
# iter 5500: test accuracy 0.904389
# iter 5600: train accuracy 0.975134
# iter 5600: test accuracy 0.907524
# iter 5700: train accuracy 0.97043
# iter 5700: test accuracy 0.905956
# iter 5800: train accuracy 0.973118
# iter 5800: test accuracy 0.909091
# iter 5900: train accuracy 0.965054
# iter 5900: test accuracy 0.899687
# iter 6000: train accuracy 0.971774
# iter 6000: test accuracy 0.915361
# iter 6100: train accuracy 0.973118
# iter 6100: test accuracy 0.909091
# iter 6200: train accuracy 0.974462
# iter 6200: test accuracy 0.913793
# iter 6300: train accuracy 0.975134
# iter 6300: test accuracy 0.912226
# iter 6400: train accuracy 0.97043
# iter 6400: test accuracy 0.907524
# iter 6500: train accuracy 0.964382
# iter 6500: test accuracy 0.904389
# iter 6600: train accuracy 0.967742
# iter 6600: test accuracy 0.916928
# iter 6700: train accuracy 0.973118
# iter 6700: test accuracy 0.905956
# iter 6800: train accuracy 0.97379
# iter 6800: test accuracy 0.909091
# iter 6900: train accuracy 0.975806
# iter 6900: test accuracy 0.912226
# iter 7000: train accuracy 0.971774
# iter 7000: test accuracy 0.905956
# iter 7100: train accuracy 0.972446
# iter 7100: test accuracy 0.909091
# iter 7200: train accuracy 0.974462
# iter 7200: test accuracy 0.909091
# iter 7300: train accuracy 0.977151
# iter 7300: test accuracy 0.905956
# iter 7400: train accuracy 0.973118
# iter 7400: test accuracy 0.909091
# iter 7500: train accuracy 0.974462
# iter 7500: test accuracy 0.907524
# iter 7600: train accuracy 0.975134
# iter 7600: test accuracy 0.912226
# iter 7700: train accuracy 0.967742
# iter 7700: test accuracy 0.915361
# iter 7800: train accuracy 0.971774
# iter 7800: test accuracy 0.901254
# iter 7900: train accuracy 0.975134
# iter 7900: test accuracy 0.907524
# iter 8000: train accuracy 0.977823
# iter 8000: test accuracy 0.910658
# iter 8100: train accuracy 0.975806
# iter 8100: test accuracy 0.909091
# iter 8200: train accuracy 0.973118
# iter 8200: test accuracy 0.904389
# iter 8300: train accuracy 0.96707
# iter 8300: test accuracy 0.907524
# iter 8400: train accuracy 0.976479
# iter 8400: test accuracy 0.904389
# iter 8500: train accuracy 0.977823
# iter 8500: test accuracy 0.901254
# iter 8600: train accuracy 0.961694
# iter 8600: test accuracy 0.899687
# iter 8700: train accuracy 0.97379
# iter 8700: test accuracy 0.907524
# iter 8800: train accuracy 0.97379
# iter 8800: test accuracy 0.909091
# iter 8900: train accuracy 0.976479
# iter 8900: test accuracy 0.905956
# iter 9000: train accuracy 0.972446
# iter 9000: test accuracy 0.907524
# iter 9100: train accuracy 0.979167
# iter 9100: test accuracy 0.904389
# iter 9200: train accuracy 0.976479
# iter 9200: test accuracy 0.904389
# iter 9300: train accuracy 0.974462
# iter 9300: test accuracy 0.905956
# iter 9400: train accuracy 0.980511
# iter 9400: test accuracy 0.902821
# iter 9500: train accuracy 0.979839
# iter 9500: test accuracy 0.904389
# iter 9600: train accuracy 0.972446
# iter 9600: test accuracy 0.901254
# iter 9700: train accuracy 0.975806
# iter 9700: test accuracy 0.901254
# iter 9800: train accuracy 0.978495
# iter 9800: test accuracy 0.905956
# iter 9900: train accuracy 0.979167
# iter 9900: test accuracy 0.898119
# iter 10000: train accuracy 0.975806
# iter 10000: test accuracy 0.901254
# iter 10100: train accuracy 0.973118
# iter 10100: test accuracy 0.910658
# iter 10200: train accuracy 0.982527
# iter 10200: test accuracy 0.910658
# iter 10300: train accuracy 0.96371
# iter 10300: test accuracy 0.893417
# iter 10400: train accuracy 0.975806
# iter 10400: test accuracy 0.901254
# iter 10500: train accuracy 0.973118
# iter 10500: test accuracy 0.901254
# iter 10600: train accuracy 0.979839
# iter 10600: test accuracy 0.907524
# iter 10700: train accuracy 0.979167
# iter 10700: test accuracy 0.905956
# iter 10800: train accuracy 0.981183
# iter 10800: test accuracy 0.909091
# iter 10900: train accuracy 0.975134
# iter 10900: test accuracy 0.905956
# iter 11000: train accuracy 0.978495
# iter 11000: test accuracy 0.905956
# iter 11100: train accuracy 0.982527
# iter 11100: test accuracy 0.909091
# iter 11200: train accuracy 0.982527
# iter 11200: test accuracy 0.909091
# iter 11300: train accuracy 0.975806
# iter 11300: test accuracy 0.899687
# iter 11400: train accuracy 0.975134
# iter 11400: test accuracy 0.901254
# iter 11500: train accuracy 0.977823
# iter 11500: test accuracy 0.905956
# iter 11600: train accuracy 0.979167
# iter 11600: test accuracy 0.904389
# iter 11700: train accuracy 0.981183
# iter 11700: test accuracy 0.901254
# iter 11800: train accuracy 0.978495
# iter 11800: test accuracy 0.913793
# iter 11900: train accuracy 0.981183
# iter 11900: test accuracy 0.909091
# iter 12000: train accuracy 0.982527
# iter 12000: test accuracy 0.910658
# iter 12100: train accuracy 0.980511
# iter 12100: test accuracy 0.907524
# iter 12200: train accuracy 0.975806
# iter 12200: test accuracy 0.909091
# iter 12300: train accuracy 0.976479
# iter 12300: test accuracy 0.910658
# iter 12400: train accuracy 0.983871
# iter 12400: test accuracy 0.907524
# iter 12500: train accuracy 0.979839
# iter 12500: test accuracy 0.904389
# iter 12600: train accuracy 0.983871
# iter 12600: test accuracy 0.907524
# iter 12700: train accuracy 0.984543
# iter 12700: test accuracy 0.910658
# iter 12800: train accuracy 0.984543
# iter 12800: test accuracy 0.905956
# iter 12900: train accuracy 0.981183
# iter 12900: test accuracy 0.907524
# iter 13000: train accuracy 0.984543
# iter 13000: test accuracy 0.907524
# iter 13100: train accuracy 0.985215
# iter 13100: test accuracy 0.907524
# iter 13200: train accuracy 0.982527
# iter 13200: test accuracy 0.912226
# iter 13300: train accuracy 0.984543
# iter 13300: test accuracy 0.907524
# iter 13400: train accuracy 0.985215
# iter 13400: test accuracy 0.909091
# iter 13500: train accuracy 0.984543
# iter 13500: test accuracy 0.899687
# iter 13600: train accuracy 0.984543
# iter 13600: test accuracy 0.912226
# iter 13700: train accuracy 0.980511
# iter 13700: test accuracy 0.907524
# iter 13800: train accuracy 0.981855
# iter 13800: test accuracy 0.912226
# iter 13900: train accuracy 0.985887
# iter 13900: test accuracy 0.904389
# iter 14000: train accuracy 0.985215
# iter 14000: test accuracy 0.904389
# iter 14100: train accuracy 0.987231
# iter 14100: test accuracy 0.902821
# iter 14200: train accuracy 0.983199
# iter 14200: test accuracy 0.910658
# iter 14300: train accuracy 0.984543
# iter 14300: test accuracy 0.909091
# iter 14400: train accuracy 0.987903
# iter 14400: test accuracy 0.905956
# iter 14500: train accuracy 0.987231
# iter 14500: test accuracy 0.912226
# iter 14600: train accuracy 0.984543
# iter 14600: test accuracy 0.910658
# iter 14700: train accuracy 0.979839
# iter 14700: test accuracy 0.901254
# iter 14800: train accuracy 0.985887
# iter 14800: test accuracy 0.909091
# iter 14900: train accuracy 0.985887
# iter 14900: test accuracy 0.902821
# iter 15000: train accuracy 0.984543
# iter 15000: test accuracy 0.913793
# iter 15100: train accuracy 0.986559
# iter 15100: test accuracy 0.909091
# iter 15200: train accuracy 0.982527
# iter 15200: test accuracy 0.912226
# iter 15300: train accuracy 0.985887
# iter 15300: test accuracy 0.913793
# iter 15400: train accuracy 0.982527
# iter 15400: test accuracy 0.916928
# iter 15500: train accuracy 0.989919
# iter 15500: test accuracy 0.909091
# iter 15600: train accuracy 0.988575
# iter 15600: test accuracy 0.904389
# iter 15700: train accuracy 0.985215
# iter 15700: test accuracy 0.905956
# iter 15800: train accuracy 0.985887
# iter 15800: test accuracy 0.909091
# iter 15900: train accuracy 0.988575
# iter 15900: test accuracy 0.905956
# iter 16000: train accuracy 0.989247
# iter 16000: test accuracy 0.905956
# iter 16100: train accuracy 0.988575
# iter 16100: test accuracy 0.910658
# iter 16200: train accuracy 0.987231
# iter 16200: test accuracy 0.909091
# iter 16300: train accuracy 0.987231
# iter 16300: test accuracy 0.912226
# iter 16400: train accuracy 0.989247
# iter 16400: test accuracy 0.913793
# iter 16500: train accuracy 0.983871
# iter 16500: test accuracy 0.913793
# iter 16600: train accuracy 0.992608
# iter 16600: test accuracy 0.910658
# iter 16700: train accuracy 0.979167
# iter 16700: test accuracy 0.910658
# iter 16800: train accuracy 0.989247
# iter 16800: test accuracy 0.907524
# iter 16900: train accuracy 0.989919
# iter 16900: test accuracy 0.910658
# iter 17000: train accuracy 0.990591
# iter 17000: test accuracy 0.912226
# iter 17100: train accuracy 0.986559
# iter 17100: test accuracy 0.910658
# iter 17200: train accuracy 0.985215
# iter 17200: test accuracy 0.909091
# iter 17300: train accuracy 0.989919
# iter 17300: test accuracy 0.909091
# iter 17400: train accuracy 0.992608
# iter 17400: test accuracy 0.912226
# iter 17500: train accuracy 0.980511
# iter 17500: test accuracy 0.905956
# iter 17600: train accuracy 0.987231
# iter 17600: test accuracy 0.915361
# iter 17700: train accuracy 0.985887
# iter 17700: test accuracy 0.902821
# iter 17800: train accuracy 0.989919
# iter 17800: test accuracy 0.915361
# iter 17900: train accuracy 0.990591
# iter 17900: test accuracy 0.909091
# iter 18000: train accuracy 0.991935
# iter 18000: test accuracy 0.910658
# iter 18100: train accuracy 0.990591
# iter 18100: test accuracy 0.909091
# iter 18200: train accuracy 0.990591
# iter 18200: test accuracy 0.905956
# iter 18300: train accuracy 0.992608
# iter 18300: test accuracy 0.909091
# iter 18400: train accuracy 0.986559
# iter 18400: test accuracy 0.910658
# iter 18500: train accuracy 0.980511
# iter 18500: test accuracy 0.912226
# iter 18600: train accuracy 0.990591
# iter 18600: test accuracy 0.910658
# iter 18700: train accuracy 0.974462
# iter 18700: test accuracy 0.894984
# iter 18800: train accuracy 0.989919
# iter 18800: test accuracy 0.909091
# iter 18900: train accuracy 0.977823
# iter 18900: test accuracy 0.907524
# iter 19000: train accuracy 0.99328
# iter 19000: test accuracy 0.909091
# iter 19100: train accuracy 0.979839
# iter 19100: test accuracy 0.912226
# iter 19200: train accuracy 0.989247
# iter 19200: test accuracy 0.909091
# iter 19300: train accuracy 0.991935
# iter 19300: test accuracy 0.913793
# iter 19400: train accuracy 0.984543
# iter 19400: test accuracy 0.910658
# iter 19500: train accuracy 0.987231
# iter 19500: test accuracy 0.902821
# iter 19600: train accuracy 0.987903
# iter 19600: test accuracy 0.902821
# iter 19700: train accuracy 0.99328
# iter 19700: test accuracy 0.907524
# iter 19800: train accuracy 0.986559
# iter 19800: test accuracy 0.910658
# iter 19900: train accuracy 0.992608
# iter 19900: test accuracy 0.912226
# iter 20000: train accuracy 0.983199
# iter 20000: test accuracy 0.904389
